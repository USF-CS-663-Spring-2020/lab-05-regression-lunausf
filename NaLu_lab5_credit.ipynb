# %%
import pandas as pd

# Read the data
df = pd.read_csv('Credit.csv')
df
# Out:
#      Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender  \
# 0             1   14.891   3606     283      2   34         11    Male
# 1             2  106.025   6645     483      3   82         15  Female
# 2             3  104.593   7075     514      4   71         11    Male
# 3             4  148.924   9504     681      3   36         11  Female
# 4             5   55.882   4897     357      2   68         16    Male
# ..          ...      ...    ...     ...    ...  ...        ...     ...
# 395         396   12.096   4100     307      3   32         13    Male
# 396         397   13.364   3838     296      5   65         17    Male
# 397         398   57.872   4171     321      5   67         12  Female
# 398         399   37.728   2525     192      1   44         13    Male
# 399         400   18.701   5524     415      5   64          7  Female
#
#     Student Married         Ethnicity  Balance
# 0        No     Yes         Caucasian      333
# ...

# %%
#plot predictor against target, limit is target and predictor is income

df.plot(kind='scatter', x='Income', y='Limit')

# %%
import seaborn as sns 
plot = sns.lmplot(x='Income', y='Limit', data=df)

# %%
# This data is appropriate the SLR. 
# We can see the error term is randomly distributed, is not exclusively below or high above, 
# error distance does not increase or decrease with change with x
r1 = sns.residplot('Income', 'Limit', data=df)
r1.set(xlabel='Income', ylabel='Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Income')]

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression() #fit regression 
lin_reg.fit(df[['Income']], df['Limit'])
lin_reg
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_ #slop
# Out:
# array([51.8750206])

# %%
lin_reg.intercept_  #intercept
# Out:
# 2389.8694089155265

# %%
#plot predictor against target, limit is target and predictor is Rating
df.plot(kind='scatter', x='Rating', y='Limit')

# %%
plot = sns.lmplot(y='Limit', x='Rating', data=df)

# %%
# This data is appropriate the SLR. 
# We can see the error term is randomly distributed, is not exclusively below or high above, 
# error distance does not increase or decrease with change with x
r1 = sns.residplot('Rating', 'Limit', data=df)
r1.set(xlabel='Rating', ylabel='Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Rating')]

# %%
lin_reg = LinearRegression() #fit regression 
lin_reg.fit(df[['Rating']], df['Limit'])
lin_reg
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_ #slop
# Out:
# array([14.87160712])

# %%
lin_reg.intercept_  #intercept
# Out:
# -542.928229986901

# %%
#plot predictor against target, limit is target and predictor is Cards
df.plot(kind='scatter', x='Cards', y='Limit')

# %%
plot = sns.lmplot(y='Limit', x='Cards', data=df)

# %%
# This data is not appropriate the SLR. 
# We can see the error term is not randomly distributed
# The positive error goes as high as 8000, while the negative error goes as low as -4000
# the error terms distribution appears not symmetric
r1 = sns.residplot('Cards', 'Limit', data=df)
r1.set(xlabel='Cards', ylabel='Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Cards')]

# %%
lin_reg = LinearRegression() #fit regression 
lin_reg.fit(df[['Cards']], df['Limit'])
lin_reg
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_ #slop
# Out:
# array([14.87160712])

# %%
lin_reg.intercept_  #intercept
# Out:
# -542.928229986901

# %%
#plot predictor against target, limit is target and predictor is Age
df.plot(kind='scatter', x='Age', y='Limit')

# %%
plot = sns.lmplot(y='Limit', x='Age', data=df)

# %%
# This data is not appropriate the SLR. 
# We can see the error term is not randomly distributed
# The positive error goes higher than 8000, while the negative error goes as low as -4000
# The positive error terms are more sparse than the negative error terms
# the error terms distribution appears not symmetric
r1 = sns.residplot('Age', 'Limit', data=df)
r1.set(xlabel='Age', ylabel='Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Age')]

# %%
lin_reg = LinearRegression() #fit regression 
lin_reg.fit(df[['Age']], df['Limit'])
lin_reg
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_ #slop
# Out:
# array([14.87160712])

# %%
lin_reg.intercept_  #intercept
# Out:
# -542.928229986901

# %%
#plot predictor against target, limit is target and predictor is Education
df.plot(kind='scatter', x='Education', y='Limit')

# %%
plot = sns.lmplot(y='Limit', x='Education', data=df)

# %%
# This data is not appropriate the SLR. 
# We can see the error term is not randomly distributed
# The positive error goes higher than 8000, while the negative error goes as low as -4000
# The positive error terms are more sparse than the negative error terms
# the error terms distribution appears not symmetric
r1 = sns.residplot('Education', 'Limit', data=df)
r1.set(xlabel='Education', ylabel='Residuals')
# Out:
# [Text(0, 0.5, 'Residuals'), Text(0.5, 0, 'Education')]

# %%
lin_reg = LinearRegression() #fit regression 
lin_reg.fit(df[['Education']], df['Limit'])
lin_reg
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_ #slop
# Out:
# array([-17.39235309])

# %%
lin_reg.intercept_  #intercept
# Out:
# 4969.527149089043
